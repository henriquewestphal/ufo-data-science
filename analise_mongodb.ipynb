# %%
import pandas as pd 
import Util
import re
from pandas.io.json import json_normalize
import json

# %%
cliente_MongoDB_db_clima = Util.fnc_Conecta_Base_Documentos('', '', 'localhost', '27017', 'dbclima')
db_clima = cliente_MongoDB_db_clima.dbclima

# %%
clima_consolidado = db_clima.clima_consolidado

# %%
df = json_normalize(list(clima_consolidado.find()))

# %%
df
# Out:
#                             _id   ano          cidade       cor dia estado  \
# 0      5c105ed1a634e104b5a09c60  1997         Olympia       NaN  14     WA
# 1      5c105ed1a634e104b5a09c61  1997          Renton    YELLOW  14     WA
# 2      5c105ed1a634e104b5a09c62  1997          Renton       NaN  14     WA
# 3      5c105ed1a634e104b5a09c63  1997         Olympia       NaN  14     WA
# 4      5c105ed1a634e104b5a09c64  1997         Olympia       NaN  14     WA
# 5      5c105ed1a634e104b5a09c65  1997         Chester       NaN  15     NJ
# 6      5c105ed1a634e104b5a09c66  1997         Chester       NaN  15     NJ
# 7      5c105ed1a634e104b5a09c67  1997       Salisbury       NaN  24     MD
# 8      5c105ed1a634e104b5a09c68  1997       Salisbury    YELLOW  24     MD
# 9      5c105ed2a634e104b5a09c69  1997            Reno       RED  09     NV
# 10     5c105ed2a634e104b5a09c6a  1997            Reno       RED  09     NV
# ...

# %%
df[['history.observations.wdird','history.observations.conds','estado', 'ano']]
# Out:
#       history.observations.wdird history.observations.conds estado   ano
# 0                              0                   Overcast     WA  1997
# 1                            140                      Clear     WA  1997
# 2                            140                      Clear     WA  1997
# 3                              0                   Overcast     WA  1997
# 4                              0                   Overcast     WA  1997
# 5                            310                   Overcast     NJ  1997
# 6                            310                   Overcast     NJ  1997
# 7                              0                   Overcast     MD  1997
# 8                              0                   Overcast     MD  1997
# 9                            310                 Light Snow     NV  1997
# 10                           310                 Light Snow     NV  1997
# 11                           310                 Light Snow     NV  1997
# ...

# %%
df[df.columns[pd.Series(df.columns.str.startswith('history'))]].head()
# Out:
#   history.observations.conds history.observations.dewpti  \
# 0                   Overcast                        39.0
# 1                      Clear                        33.8
# 2                      Clear                        33.8
# 3                   Overcast                        39.0
# 4                   Overcast                        39.0
#
#   history.observations.dewptm history.observations.fog  \
# 0                         3.9                        0
# 1                         1.0                        0
# 2                         1.0                        0
# 3                         3.9                        0
# 4                         3.9                        0
#
#   history.observations.hail history.observations.heatindexi  \
# 0                         0                           -9999
# 1                         0                           -9999
# 2                         0                           -9999
# ...

# %%
df.loc[(df['cidade'] == 'Olympia') & (df['history.observations.conds'] == 'Overcast')]
# Out:
#                             _id   ano   cidade  cor dia estado    formato  \
# 0      5c105ed1a634e104b5a09c60  1997  Olympia  NaN  14     WA  FORMATION
# 3      5c105ed1a634e104b5a09c63  1997  Olympia  NaN  14     WA   FIREBALL
# 4      5c105ed1a634e104b5a09c64  1997  Olympia  NaN  14     WA  FORMATION
# 270    5c183997a634e100213698dd  1997  Olympia  NaN  14     WA   Fireball
# 8856   5c183d27a634e1002136ba67  2015  Olympia  NaN  19     WA       Disk
# 13920  5c183daba634e1002136ce2f  2017  Olympia  NaN  28     WA      Light
#
#       history.observations.conds history.observations.dewpti  \
# 0                       Overcast                        39.0
# 3                       Overcast                        39.0
# 4                       Overcast                        39.0
# 270                     Overcast                        39.0
# 8856                    Overcast                        55.9
# 13920                   Overcast                        37.9
#
# ...

# %%
array = ['NM', 'AK']
df.loc[df['estado'].isin(array)].head()
# Out:
#                          _id   ano       cidade        cor dia estado  \
# 29  5c105edfa634e104b5a09c7d  1998     Auke Bay   RED BLUE  15     AK
# 30  5c105edfa634e104b5a09c7e  1998     Auke Bay  RED GREEN  15     AK
# 59  5c105eeea634e104b5a09c9b  1999  Albuquerque        RED  22     NM
# 60  5c105eefa634e104b5a09c9c  1999  Albuquerque        NaN  22     NM
# 81  5c105efba634e104b5a09cb1  1999       Seward        NaN  02     AK
#
#      formato history.observations.conds history.observations.dewpti  \
# 29     LIGHT                   Overcast                        46.0
# 30     LIGHT                   Overcast                        46.0
# 59  FIREBALL              Mostly Cloudy                        39.9
# 60  TRIANGLE              Mostly Cloudy                        39.9
# 81     LIGHT                 Light Rain                        50.0
#
#    history.observations.dewptm   ...   history.observations.wdird  \
# ...

# %%
filtro_cidade = df[df['cidade'] == 'Seward']
filtro_cidade[['estado', 'dia']]
# Out:
#     estado dia
# 81      AK  02
# 82      AK  02
# 300     AK  02

# %%
df[['estado','dia']]
# Out:
#       estado dia
# 0         WA  14
# 1         WA  14
# 2         WA  14
# 3         WA  14
# 4         WA  14
# 5         NJ  15
# 6         NJ  15
# 7         MD  24
# 8         MD  24
# 9         NV  09
# 10        NV  09
# 11        NV  09
# 12        NV  09
# 13        MS  31
# 14        MS  31
# 15        FL  07
# 16        FL  07
# 17        MA  04
# 18        MA  04
# 19        VA  28
# 20        VA  28
# 21        TX  03
# 22        TX  03
# 23        AZ  07
# 24        AZ  07
# 25        NV  19
# 26        NV  19
# 27        UT  15
# 28        UT  15
# 29        AK  15
# ...      ...  ..
# 16919     GA  03
# 16920     CA  03
# 16921     HI  03
# 16922     FL  02
# 16923     MI  02
# 16924     CA  02
# 16925     LA  02
# 16926     NM  02
# 16927     NY  02
# 16928     GA  02
# 16929     IN  02
# 16930     AZ  02
# 16931     VA  01
# 16932     SC  01
# 16933     CA  01
# 16934     MD  01
# 16935     FL  01
# 16936     NY  01
# 16937     FL  01
# 16938     VA  01
# ...
